# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Rudolf Horvat**
#
# Current occupation: IT manager, Desired occupation: Data scientist

# %% [markdown]
# *I would like to be a data scientist because in my career so far I have always had the most fun on projects that included modeling and programming*

# %% [markdown]
# ### The following code calculates sin(0.5*Pi) ###

# %%
import math

math.sin(0.5*math.pi)
# Out:
# 1.0

# %% [markdown]
# ---
# - one
# - two
# - three
# ---
#
# 1. first
# 2. second
# 3. third
# ---
# |Syntax | Description |
# | ----------- | ----------- |
# | Header | Title |
# | Paragraph | Text |
#
# ---
# [this is a link to Google](https://www.google.com)
#
# ---
# ![IBM logo](https://th.bing.com/th/id/OIP.Bs2PlI-wmfFiYzgWNRO0pgHaDO?w=290&h=152&c=7&r=0&o=5&pid=1.7)
#
# ---
# `math.sin(0.5*math.pi)`
